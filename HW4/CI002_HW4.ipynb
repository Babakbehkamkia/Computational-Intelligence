# %% [markdown]
# # Your info
#
# Full name: Babak Behkam Kia
#
# Student ID: 98521099

# %% [markdown]
# #**Q2**

# %%
# Q2_graded

# !pip install simpful
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: simpful in /usr/local/lib/python3.7/dist-packages (2.6.3)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from simpful) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from simpful) (2.23.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from simpful) (1.21.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->simpful) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->simpful) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->simpful) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->simpful) (3.0.4)

# %%
# Q2_graded

from simpful import *

FS = FuzzySystem()

player_price = AutoTriangle(6, terms=['very_cheap', 'cheap', 'normal', 'expensive', 'very_expensive', 'extremely_expensive'], universe_of_discourse=[20,600])
player_age = AutoTriangle(5, terms=['very_young', 'young', 'middle_age', 'old', 'very_old'], universe_of_discourse=[18,35])
last_5_maches = AutoTriangle(3, terms=['bad', 'medium', 'good'], universe_of_discourse=[0,5])

FS.add_linguistic_variable("price_goalkeeper_Foolad", player_price)
FS.add_linguistic_variable("age_goalkeeper_Foolad", player_age)

FS.add_linguistic_variable("price_left_difender_Foolad", player_price)
FS.add_linguistic_variable("age_left_difender_Foolad", player_age)

FS.add_linguistic_variable("price_right_difender_Foolad", player_price)
FS.add_linguistic_variable("age_right_difender_Foolad", player_age)

FS.add_linguistic_variable("price_mid_difender_1_Foolad", player_price)
FS.add_linguistic_variable("age_mid_difender_1_Foolad", player_age)

FS.add_linguistic_variable("price_mid_difender_2_Foolad", player_price)
FS.add_linguistic_variable("age_mid_difender_2_Foolad", player_age)

FS.add_linguistic_variable("price_mid_fielder_1_Foolad", player_price)
FS.add_linguistic_variable("age_mid_fielder_1_Foolad", player_age)

FS.add_linguistic_variable("price_mid_fielder_2_Foolad", player_price)
FS.add_linguistic_variable("age_mid_fielder_2_Foolad", player_age)

FS.add_linguistic_variable("price_mid_fielder_3_Foolad", player_price)
FS.add_linguistic_variable("age_mid_fielder_3_Foolad", player_age)

FS.add_linguistic_variable("price_right_forward_Foolad", player_price)
FS.add_linguistic_variable("age_right_forward_Foolad", player_age)

FS.add_linguistic_variable("price_left_forward_Foolad", player_price)
FS.add_linguistic_variable("age_left_forward_Foolad", player_age)

FS.add_linguistic_variable("price_center_forward_Foolad", player_price)
FS.add_linguistic_variable("age_center_forward_Foolad", player_age)


# ====================================


FS.add_linguistic_variable("price_goalkeeper_Sepahan", player_price)
FS.add_linguistic_variable("age_goalkeeper_Sepahan", player_age)

FS.add_linguistic_variable("price_left_difender_Sepahan", player_price)
FS.add_linguistic_variable("age_left_difender_Sepahan", player_age)

FS.add_linguistic_variable("price_right_difender_Sepahan", player_price)
FS.add_linguistic_variable("age_right_difender_Sepahan", player_age)

FS.add_linguistic_variable("price_mid_difender_1_Sepahan", player_price)
FS.add_linguistic_variable("age_mid_difender_1_Sepahan", player_age)

FS.add_linguistic_variable("price_mid_difender_2_Sepahan", player_price)
FS.add_linguistic_variable("age_mid_difender_2_Sepahan", player_age)

FS.add_linguistic_variable("price_mid_fielder_1_Sepahan", player_price)
FS.add_linguistic_variable("age_mid_fielder_1_Sepahan", player_age)

FS.add_linguistic_variable("price_mid_fielder_2_Sepahan", player_price)
FS.add_linguistic_variable("age_mid_fielder_2_Sepahan", player_age)

FS.add_linguistic_variable("price_mid_fielder_3_Sepahan", player_price)
FS.add_linguistic_variable("age_mid_fielder_3_Sepahan", player_age)

FS.add_linguistic_variable("price_right_forward_Sepahan", player_price)
FS.add_linguistic_variable("age_right_forward_Sepahan", player_age)

FS.add_linguistic_variable("price_left_forward_Sepahan", player_price)
FS.add_linguistic_variable("age_left_forward_Sepahan", player_age)

FS.add_linguistic_variable("price_center_forward_Sepahan", player_price)
FS.add_linguistic_variable("age_center_forward_Sepahan", player_age)


# =====================


FS.add_linguistic_variable("performance_Foolad", last_5_maches)
FS.add_linguistic_variable("performance_Sepahan", last_5_maches)


result = AutoTriangle(3, terms=['Sepahan_win', 'tie', 'Foolad_win'], universe_of_discourse=[-10,10])
FS.add_linguistic_variable("result_1", result)
FS.add_linguistic_variable("result_2", result)
FS.add_linguistic_variable("result_3", result)
FS.add_linguistic_variable("result_4", result)
FS.add_linguistic_variable("result_5", result)
FS.add_linguistic_variable("result_6", result)
# Out:
#   ____  __  _  _  ____  ____  _  _  __
#  / ___)(  )( \/ )(  _ \(  __)/ )( \(  ) v2.6.3
#  \___ \ )( / \/ \ ) __/ ) _) ) \/ (/ (_/\
#  (____/(__)\_)(_/(__)  (__)  \____/\____/
#
#  Created by Marco S. Nobile (m.s.nobile@tue.nl)
#  and Simone Spolaor (simone.spolaor@unimib.it)

# %%
# Q2_graded

# res1 = goal keeper value
# res2 = defender value
# res3 = forwards value
# res4 = goalkeeper value vs forward value
# res5 = defender value vs forward value
# res6 = last 5 maches

# %%
# Q2_graded

Rules1 = [
        "IF (price_goalkeeper_Foolad IS expensive) THEN (result_1 IS Foolad_win)",
        "IF (price_goalkeeper_Sepahan IS expensive) THEN (result_1 IS Sepahan_win)",
        "IF (age_goalkeeper_Sepahan IS middle_age) THEN (result_1 IS Sepahan_win)",
        "IF (age_goalkeeper_Foolad IS very_old) THEN (result_1 IS Sepahan_win)",
        "IF (age_goalkeeper_Sepahan IS very_old) THEN (result_1 IS Foolad_win)",
        "IF (price_goalkeeper_Foolad IS cheap) THEN (result_1 IS Sepahan_win)",
]

# %%
# Q2_graded

Rules2 = [
        "IF (price_mid_difender_1_Foolad IS expensive) THEN (result_2 IS Foolad_win)",
        "IF (price_mid_difender_1_Sepahan IS expensive) THEN (result_2 IS Sepahan_win)",
        "IF (age_mid_difender_1_Foolad IS middle_age) THEN (result_2 IS Foolad_win)",
        "IF (age_mid_difender_1_Sepahan IS middle_age) THEN (result_2 IS Sepahan_win)",
        "IF (age_mid_difender_1_Foolad IS very_old) THEN (result_2 IS Sepahan_win)",
        "IF (age_mid_difender_1_Sepahan IS very_old) THEN (result_2 IS Foolad_win)",
        "IF (price_mid_difender_1_Foolad IS cheap) THEN (result_2 IS Sepahan_win)",
        "IF (price_mid_difender_1_Sepahan IS cheap) THEN (result_2 IS Foolad_win)",

        "IF (price_mid_difender_2_Foolad IS expensive) THEN (result_2 IS Foolad_win)",
        "IF (price_mid_difender_2_Sepahan IS expensive) THEN (result_2 IS Sepahan_win)",
        "IF (age_mid_difender_2_Foolad IS middle_age) THEN (result_2 IS Foolad_win)",
        "IF (age_mid_difender_2_Sepahan IS middle_age) THEN (result_2 IS Sepahan_win)",
        "IF (age_mid_difender_2_Foolad IS very_old) THEN (result_2 IS Sepahan_win)",
        "IF (age_mid_difender_2_Sepahan IS very_old) THEN (result_2 IS Foolad_win)",
        "IF (price_mid_difender_2_Foolad IS cheap) THEN (result_2 IS Sepahan_win)",
        "IF (price_mid_difender_2_Sepahan IS cheap) THEN (result_2 IS Foolad_win)",

        "IF (price_left_difender_Foolad IS expensive) THEN (result_2 IS Foolad_win)",
        "IF (price_left_difender_Sepahan IS expensive) THEN (result_2 IS Sepahan_win)",
        "IF (age_left_difender_Foolad IS middle_age) THEN (result_2 IS Foolad_win)",
        "IF (age_left_difender_Sepahan IS middle_age) THEN (result_2 IS Sepahan_win)",
        "IF (age_left_difender_Foolad IS very_old) THEN (result_2 IS Sepahan_win)",
        "IF (age_left_difender_Sepahan IS very_old) THEN (result_2 IS Foolad_win)",
        "IF (price_left_difender_Foolad IS cheap) THEN (result_2 IS Sepahan_win)",
        "IF (price_left_difender_Sepahan IS cheap) THEN (result_2 IS Foolad_win)",

        "IF (price_right_difender_Foolad IS expensive) THEN (result_2 IS Foolad_win)",
        "IF (price_right_difender_Sepahan IS expensive) THEN (result_2 IS Sepahan_win)",
        "IF (age_right_difender_Foolad IS middle_age) THEN (result_2 IS Foolad_win)",
        "IF (age_right_difender_Sepahan IS middle_age) THEN (result_2 IS Sepahan_win)",
        "IF (age_right_difender_Foolad IS very_old) THEN (result_2 IS Sepahan_win)",
        "IF (age_right_difender_Sepahan IS very_old) THEN (result_2 IS Foolad_win)",
        "IF (price_right_difender_Foolad IS cheap) THEN (result_2 IS Sepahan_win)",
        "IF (price_right_difender_Sepahan IS cheap) THEN (result_2 IS Foolad_win)"
]

# %%
# Q2_graded

Rules3 = [
        "IF (price_center_forward_Foolad IS expensive) THEN (result_3 IS Foolad_win)",
        "IF (price_center_forward_Sepahan IS expensive) THEN (result_3 IS Sepahan_win)",
        "IF (age_center_forward_Foolad IS middle_age) THEN (result_3 IS Foolad_win)",
        "IF (age_center_forward_Sepahan IS middle_age) THEN (result_3 IS Sepahan_win)",
        "IF (age_center_forward_Foolad IS very_old) THEN (result_3 IS Sepahan_win)",
        "IF (age_center_forward_Sepahan IS very_old) THEN (result_3 IS Foolad_win)",
        "IF (price_center_forward_Foolad IS cheap) THEN (result_3 IS Sepahan_win)",
        "IF (price_center_forward_Sepahan IS cheap) THEN (result_3 IS Foolad_win)",

        "IF (price_left_forward_Foolad IS expensive) THEN (result_3 IS Foolad_win)",
        "IF (price_left_forward_Sepahan IS expensive) THEN (result_3 IS Sepahan_win)",
        "IF (age_left_forward_Foolad IS middle_age) THEN (result_3 IS Foolad_win)",
        "IF (age_left_forward_Sepahan IS middle_age) THEN (result_3 IS Sepahan_win)",
        "IF (age_left_forward_Foolad IS very_old) THEN (result_3 IS Sepahan_win)",
        "IF (age_left_forward_Sepahan IS very_old) THEN (result_3 IS Foolad_win)",
        "IF (price_left_forward_Foolad IS cheap) THEN (result_3 IS Sepahan_win)",
        "IF (price_left_forward_Sepahan IS cheap) THEN (result_3 IS Foolad_win)",

        "IF (price_right_forward_Foolad IS expensive) THEN (result_3 IS Foolad_win)",
        "IF (price_right_forward_Sepahan IS expensive) THEN (result_3 IS Sepahan_win)",
        "IF (age_right_forward_Foolad IS middle_age) THEN (result_3 IS Foolad_win)",
        "IF (age_right_forward_Sepahan IS middle_age) THEN (result_3 IS Sepahan_win)",
        "IF (age_right_forward_Foolad IS very_old) THEN (result_3 IS Sepahan_win)",
        "IF (age_right_forward_Sepahan IS very_old) THEN (result_3 IS Foolad_win)",
        "IF (price_right_forward_Foolad IS cheap) THEN (result_3 IS Sepahan_win)",
        "IF (price_right_forward_Sepahan IS cheap) THEN (result_3 IS Foolad_win)"
]

# %%
# Q2_graded

Rules4 = [
        "IF (price_goalkeeper_Foolad IS expensive) AND (price_center_forward_Sepahan IS expensive) THEN (result_4 IS tie)",
        "IF (price_goalkeeper_Sepahan IS expensive) AND (price_center_forward_Foolad IS expensive) THEN (result_4 IS tie)",
        "IF (age_goalkeeper_Foolad IS middle_age) AND (age_center_forward_Sepahan IS young) THEN (result_4 IS Foolad_win)",
        "IF (age_goalkeeper_Sepahan IS middle_age) AND (age_center_forward_Foolad IS very_old) THEN (result_4 IS Sepahan_win)",
        "IF (age_goalkeeper_Foolad IS very_old) AND (age_center_forward_Sepahan IS middle_age) THEN (result_4 IS Sepahan_win)",
        "IF (age_goalkeeper_Sepahan IS very_old) AND (age_center_forward_Foolad IS young) THEN (result_4 IS Foolad_win)",
        "IF (price_goalkeeper_Foolad IS normal) AND (price_center_forward_Sepahan IS expensive) THEN (result_4 IS Sepahan_win)",
        "IF (price_goalkeeper_Sepahan IS normal) AND (price_center_forward_Foolad IS expensive) THEN (result_4 IS Foolad_win)"       
]

# %%
# Q2_graded

Rules5 = [
        "IF (age_mid_difender_1_Foolad IS young) AND (age_mid_difender_2_Foolad IS young) AND (age_center_forward_Sepahan IS very_old) THEN (result_5 IS Foolad_win)",
        "IF (age_mid_difender_1_Sepahan IS young) AND (age_mid_difender_2_Sepahan IS young) AND (age_center_forward_Foolad IS very_old) THEN (result_5 IS Sepahan_win)",
        "IF (age_mid_difender_1_Foolad IS very_old) AND (age_mid_difender_2_Foolad IS middle_age) AND (age_center_forward_Sepahan IS young) THEN (result_5 IS Sepahan_win)",
        "IF (age_mid_difender_1_Sepahan IS old) AND (age_mid_difender_2_Sepahan IS young) AND (age_center_forward_Foolad IS old) THEN (result_5 IS Sepahan_win)",
        "IF (age_mid_difender_1_Sepahan IS old) AND (age_mid_difender_2_Sepahan IS old) AND (age_center_forward_Foolad IS middle_age) THEN (result_5 IS Foolad_win)",

        "IF (age_left_difender_Foolad IS young) AND (age_right_forward_Sepahan IS very_old) THEN (result_5 IS Foolad_win)",
        "IF (age_left_difender_Sepahan IS young) AND (age_right_forward_Foolad IS very_old) THEN (result_5 IS Sepahan_win)",
        "IF (age_left_difender_Foolad IS very_old) AND (age_right_forward_Sepahan IS young) THEN (result_5 IS Sepahan_win)",
        "IF (age_left_difender_Sepahan IS old) AND (age_right_forward_Foolad IS old) THEN (result_5 IS Sepahan_win)",
        "IF (age_left_difender_Sepahan IS old) AND (age_right_forward_Foolad IS middle_age) THEN (result_5 IS Foolad_win)",

        "IF (age_right_difender_Foolad IS young) AND (age_left_forward_Sepahan IS very_old) THEN (result_5 IS Foolad_win)",
        "IF (age_right_difender_Sepahan IS young) AND (age_left_forward_Foolad IS very_old) THEN (result_5 IS Sepahan_win)",
        "IF (age_right_difender_Foolad IS very_old) AND (age_left_forward_Sepahan IS young) THEN (result_5 IS Sepahan_win)",
        "IF (age_right_difender_Sepahan IS old) AND (age_left_forward_Foolad IS old) THEN (result_5 IS Sepahan_win)",
        "IF (age_right_difender_Sepahan IS old) AND (age_left_forward_Foolad IS middle_age) THEN (result_5 IS Foolad_win)",

        "IF (price_mid_difender_1_Foolad IS expensive) AND (price_mid_difender_2_Foolad IS expensive) AND (price_center_forward_Sepahan IS very_cheap) THEN (result_5 IS Foolad_win)",
        "IF (price_mid_difender_1_Sepahan IS expensive) AND (price_mid_difender_2_Sepahan IS expensive) AND (price_center_forward_Foolad IS very_cheap) THEN (result_5 IS Sepahan_win)",
        "IF (price_mid_difender_1_Foolad IS very_cheap) AND (price_mid_difender_2_Foolad IS normal) AND (price_center_forward_Sepahan IS expensive) THEN (result_5 IS Sepahan_win)",
        "IF (price_mid_difender_1_Sepahan IS cheap) AND (price_mid_difender_2_Sepahan IS expensive) AND (price_center_forward_Foolad IS cheap) THEN (result_5 IS Sepahan_win)",
        "IF (price_mid_difender_1_Sepahan IS cheap) AND (price_mid_difender_2_Sepahan IS cheap) AND (price_center_forward_Foolad IS normal) THEN (result_5 IS Foolad_win)",
        
        "IF (price_left_difender_Foolad IS expensive) AND (price_right_forward_Sepahan IS very_cheap) THEN (result_5 IS Foolad_win)",
        "IF (price_left_difender_Sepahan IS expensive) AND (price_right_forward_Foolad IS very_cheap) THEN (result_5 IS Sepahan_win)",
        "IF (price_left_difender_Foolad IS very_cheap) AND (price_right_forward_Sepahan IS expensive) THEN (result_5 IS Sepahan_win)",
        "IF (price_left_difender_Sepahan IS cheap) AND (price_right_forward_Foolad IS cheap) THEN (result_5 IS Sepahan_win)",
        "IF (price_left_difender_Sepahan IS cheap) AND (price_right_forward_Foolad IS normal) THEN (result_5 IS Foolad_win)",

        "IF (price_right_difender_Foolad IS expensive) AND (price_left_forward_Sepahan IS very_cheap) THEN (result_5 IS Foolad_win)",
        "IF (price_right_difender_Sepahan IS expensive) AND (price_left_forward_Foolad IS very_cheap) THEN (result_5 IS Sepahan_win)",
        "IF (price_right_difender_Foolad IS very_cheap) AND (price_left_forward_Sepahan IS expensive) THEN (result_5 IS Sepahan_win)",
        "IF (price_right_difender_Sepahan IS cheap) AND (price_left_forward_Foolad IS cheap) THEN (result_5 IS Sepahan_win)",
        "IF (price_right_difender_Sepahan IS cheap) AND (price_left_forward_Foolad IS normal) THEN (result_5 IS Foolad_win)",
        
]

# %%
# Q2_graded

Rules6 = [
        "IF (performance_Foolad IS bad) THEN (result_6 IS Sepahan_win)",
        "IF (performance_Sepahan IS good) THEN (result_6 IS Sepahan_win)",
        "IF (performance_Foolad IS bad) AND (performance_Sepahan IS bad) THEN (result_6 IS tie)",
        "IF (performance_Foolad IS medium) AND (performance_Sepahan IS medium) THEN (result_6 IS tie)"
]

# %%
# Q2_graded

FS.add_rules(Rules1 + Rules2 + Rules3 + Rules4 + Rules5 + Rules6, verbose=True)
# Out:
#  * Simple clause with parentheses matched
#  * Rule: c.(price_goalkeeper_Foolad IS expensive)
#  * Added rule IF c.(price_goalkeeper_Foolad IS expensive) THEN ('result_1', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_goalkeeper_Sepahan IS expensive)
#  * Added rule IF c.(price_goalkeeper_Sepahan IS expensive) THEN ('result_1', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_goalkeeper_Sepahan IS middle_age)
#  * Added rule IF c.(age_goalkeeper_Sepahan IS middle_age) THEN ('result_1', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_goalkeeper_Foolad IS very_old)
#  * Added rule IF c.(age_goalkeeper_Foolad IS very_old) THEN ('result_1', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_goalkeeper_Sepahan IS very_old)
#  * Added rule IF c.(age_goalkeeper_Sepahan IS very_old) THEN ('result_1', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_goalkeeper_Foolad IS cheap)
#  * Added rule IF c.(price_goalkeeper_Foolad IS cheap) THEN ('result_1', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_1_Foolad IS expensive)
#  * Added rule IF c.(price_mid_difender_1_Foolad IS expensive) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_1_Sepahan IS expensive)
#  * Added rule IF c.(price_mid_difender_1_Sepahan IS expensive) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_1_Foolad IS middle_age)
#  * Added rule IF c.(age_mid_difender_1_Foolad IS middle_age) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_1_Sepahan IS middle_age)
#  * Added rule IF c.(age_mid_difender_1_Sepahan IS middle_age) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_1_Foolad IS very_old)
#  * Added rule IF c.(age_mid_difender_1_Foolad IS very_old) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_1_Sepahan IS very_old)
#  * Added rule IF c.(age_mid_difender_1_Sepahan IS very_old) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_1_Foolad IS cheap)
#  * Added rule IF c.(price_mid_difender_1_Foolad IS cheap) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_1_Sepahan IS cheap)
#  * Added rule IF c.(price_mid_difender_1_Sepahan IS cheap) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_2_Foolad IS expensive)
#  * Added rule IF c.(price_mid_difender_2_Foolad IS expensive) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_2_Sepahan IS expensive)
#  * Added rule IF c.(price_mid_difender_2_Sepahan IS expensive) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_2_Foolad IS middle_age)
#  * Added rule IF c.(age_mid_difender_2_Foolad IS middle_age) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_2_Sepahan IS middle_age)
#  * Added rule IF c.(age_mid_difender_2_Sepahan IS middle_age) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_2_Foolad IS very_old)
#  * Added rule IF c.(age_mid_difender_2_Foolad IS very_old) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_2_Sepahan IS very_old)
#  * Added rule IF c.(age_mid_difender_2_Sepahan IS very_old) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_2_Foolad IS cheap)
#  * Added rule IF c.(price_mid_difender_2_Foolad IS cheap) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_2_Sepahan IS cheap)
#  * Added rule IF c.(price_mid_difender_2_Sepahan IS cheap) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_difender_Foolad IS expensive)
#  * Added rule IF c.(price_left_difender_Foolad IS expensive) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_difender_Sepahan IS expensive)
#  * Added rule IF c.(price_left_difender_Sepahan IS expensive) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_difender_Foolad IS middle_age)
#  * Added rule IF c.(age_left_difender_Foolad IS middle_age) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_difender_Sepahan IS middle_age)
#  * Added rule IF c.(age_left_difender_Sepahan IS middle_age) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_difender_Foolad IS very_old)
#  * Added rule IF c.(age_left_difender_Foolad IS very_old) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_difender_Sepahan IS very_old)
#  * Added rule IF c.(age_left_difender_Sepahan IS very_old) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_difender_Foolad IS cheap)
#  * Added rule IF c.(price_left_difender_Foolad IS cheap) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_difender_Sepahan IS cheap)
#  * Added rule IF c.(price_left_difender_Sepahan IS cheap) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_difender_Foolad IS expensive)
#  * Added rule IF c.(price_right_difender_Foolad IS expensive) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_difender_Sepahan IS expensive)
#  * Added rule IF c.(price_right_difender_Sepahan IS expensive) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_difender_Foolad IS middle_age)
#  * Added rule IF c.(age_right_difender_Foolad IS middle_age) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_difender_Sepahan IS middle_age)
#  * Added rule IF c.(age_right_difender_Sepahan IS middle_age) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_difender_Foolad IS very_old)
#  * Added rule IF c.(age_right_difender_Foolad IS very_old) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_difender_Sepahan IS very_old)
#  * Added rule IF c.(age_right_difender_Sepahan IS very_old) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_difender_Foolad IS cheap)
#  * Added rule IF c.(price_right_difender_Foolad IS cheap) THEN ('result_2', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_difender_Sepahan IS cheap)
#  * Added rule IF c.(price_right_difender_Sepahan IS cheap) THEN ('result_2', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_center_forward_Foolad IS expensive)
#  * Added rule IF c.(price_center_forward_Foolad IS expensive) THEN ('result_3', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_center_forward_Sepahan IS expensive)
#  * Added rule IF c.(price_center_forward_Sepahan IS expensive) THEN ('result_3', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_center_forward_Foolad IS middle_age)
#  * Added rule IF c.(age_center_forward_Foolad IS middle_age) THEN ('result_3', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_center_forward_Sepahan IS middle_age)
#  * Added rule IF c.(age_center_forward_Sepahan IS middle_age) THEN ('result_3', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_center_forward_Foolad IS very_old)
#  * Added rule IF c.(age_center_forward_Foolad IS very_old) THEN ('result_3', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_center_forward_Sepahan IS very_old)
#  * Added rule IF c.(age_center_forward_Sepahan IS very_old) THEN ('result_3', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_center_forward_Foolad IS cheap)
#  * Added rule IF c.(price_center_forward_Foolad IS cheap) THEN ('result_3', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_center_forward_Sepahan IS cheap)
#  * Added rule IF c.(price_center_forward_Sepahan IS cheap) THEN ('result_3', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_forward_Foolad IS expensive)
#  * Added rule IF c.(price_left_forward_Foolad IS expensive) THEN ('result_3', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_forward_Sepahan IS expensive)
#  * Added rule IF c.(price_left_forward_Sepahan IS expensive) THEN ('result_3', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_forward_Foolad IS middle_age)
#  * Added rule IF c.(age_left_forward_Foolad IS middle_age) THEN ('result_3', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_forward_Sepahan IS middle_age)
#  * Added rule IF c.(age_left_forward_Sepahan IS middle_age) THEN ('result_3', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_forward_Foolad IS very_old)
#  * Added rule IF c.(age_left_forward_Foolad IS very_old) THEN ('result_3', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_forward_Sepahan IS very_old)
#  * Added rule IF c.(age_left_forward_Sepahan IS very_old) THEN ('result_3', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_forward_Foolad IS cheap)
#  * Added rule IF c.(price_left_forward_Foolad IS cheap) THEN ('result_3', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_forward_Sepahan IS cheap)
#  * Added rule IF c.(price_left_forward_Sepahan IS cheap) THEN ('result_3', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_forward_Foolad IS expensive)
#  * Added rule IF c.(price_right_forward_Foolad IS expensive) THEN ('result_3', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_forward_Sepahan IS expensive)
#  * Added rule IF c.(price_right_forward_Sepahan IS expensive) THEN ('result_3', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_forward_Foolad IS middle_age)
#  * Added rule IF c.(age_right_forward_Foolad IS middle_age) THEN ('result_3', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_forward_Sepahan IS middle_age)
#  * Added rule IF c.(age_right_forward_Sepahan IS middle_age) THEN ('result_3', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_forward_Foolad IS very_old)
#  * Added rule IF c.(age_right_forward_Foolad IS very_old) THEN ('result_3', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_forward_Sepahan IS very_old)
#  * Added rule IF c.(age_right_forward_Sepahan IS very_old) THEN ('result_3', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_forward_Foolad IS cheap)
#  * Added rule IF c.(price_right_forward_Foolad IS cheap) THEN ('result_3', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_forward_Sepahan IS cheap)
#  * Added rule IF c.(price_right_forward_Sepahan IS cheap) THEN ('result_3', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_goalkeeper_Foolad IS expensive) AND (price_center_forward_Sepahan IS expensive)
#   -- Found (price_goalkeeper_Foolad IS expensive) *AND* (price_center_forward_Sepahan IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_goalkeeper_Foolad IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_center_forward_Sepahan IS expensive)
#  * Added rule IF f.(c.(price_goalkeeper_Foolad IS expensive) AND c.(price_center_forward_Sepahan IS expensive)) THEN ('result_4', 'tie')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_goalkeeper_Sepahan IS expensive) AND (price_center_forward_Foolad IS expensive)
#   -- Found (price_goalkeeper_Sepahan IS expensive) *AND* (price_center_forward_Foolad IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_goalkeeper_Sepahan IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_center_forward_Foolad IS expensive)
#  * Added rule IF f.(c.(price_goalkeeper_Sepahan IS expensive) AND c.(price_center_forward_Foolad IS expensive)) THEN ('result_4', 'tie')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_goalkeeper_Foolad IS middle_age) AND (age_center_forward_Sepahan IS young)
#   -- Found (age_goalkeeper_Foolad IS middle_age) *AND* (age_center_forward_Sepahan IS young)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_goalkeeper_Foolad IS middle_age)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_center_forward_Sepahan IS young)
#  * Added rule IF f.(c.(age_goalkeeper_Foolad IS middle_age) AND c.(age_center_forward_Sepahan IS young)) THEN ('result_4', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_goalkeeper_Sepahan IS middle_age) AND (age_center_forward_Foolad IS very_old)
#   -- Found (age_goalkeeper_Sepahan IS middle_age) *AND* (age_center_forward_Foolad IS very_old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_goalkeeper_Sepahan IS middle_age)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_center_forward_Foolad IS very_old)
#  * Added rule IF f.(c.(age_goalkeeper_Sepahan IS middle_age) AND c.(age_center_forward_Foolad IS very_old)) THEN ('result_4', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_goalkeeper_Foolad IS very_old) AND (age_center_forward_Sepahan IS middle_age)
#   -- Found (age_goalkeeper_Foolad IS very_old) *AND* (age_center_forward_Sepahan IS middle_age)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_goalkeeper_Foolad IS very_old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_center_forward_Sepahan IS middle_age)
#  * Added rule IF f.(c.(age_goalkeeper_Foolad IS very_old) AND c.(age_center_forward_Sepahan IS middle_age)) THEN ('result_4', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_goalkeeper_Sepahan IS very_old) AND (age_center_forward_Foolad IS young)
#   -- Found (age_goalkeeper_Sepahan IS very_old) *AND* (age_center_forward_Foolad IS young)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_goalkeeper_Sepahan IS very_old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_center_forward_Foolad IS young)
#  * Added rule IF f.(c.(age_goalkeeper_Sepahan IS very_old) AND c.(age_center_forward_Foolad IS young)) THEN ('result_4', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_goalkeeper_Foolad IS normal) AND (price_center_forward_Sepahan IS expensive)
#   -- Found (price_goalkeeper_Foolad IS normal) *AND* (price_center_forward_Sepahan IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_goalkeeper_Foolad IS normal)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_center_forward_Sepahan IS expensive)
#  * Added rule IF f.(c.(price_goalkeeper_Foolad IS normal) AND c.(price_center_forward_Sepahan IS expensive)) THEN ('result_4', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_goalkeeper_Sepahan IS normal) AND (price_center_forward_Foolad IS expensive)
#   -- Found (price_goalkeeper_Sepahan IS normal) *AND* (price_center_forward_Foolad IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_goalkeeper_Sepahan IS normal)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_center_forward_Foolad IS expensive)
#  * Added rule IF f.(c.(price_goalkeeper_Sepahan IS normal) AND c.(price_center_forward_Foolad IS expensive)) THEN ('result_4', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_mid_difender_1_Foolad IS young) AND (age_mid_difender_2_Foolad IS young) AND (age_center_forward_Sepahan IS very_old)
#   -- Found (age_mid_difender_1_Foolad IS young) *AND* (age_mid_difender_2_Foolad IS young) AND (age_center_forward_Sepahan IS very_old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_1_Foolad IS young)
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_mid_difender_2_Foolad IS young) AND (age_center_forward_Sepahan IS very_old)
#   -- Found (age_mid_difender_2_Foolad IS young) *AND* (age_center_forward_Sepahan IS very_old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_2_Foolad IS young)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_center_forward_Sepahan IS very_old)
#  * Added rule IF f.(c.(age_mid_difender_1_Foolad IS young) AND f.(c.(age_mid_difender_2_Foolad IS young) AND c.(age_center_forward_Sepahan IS very_old))) THEN ('result_5', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_mid_difender_1_Sepahan IS young) AND (age_mid_difender_2_Sepahan IS young) AND (age_center_forward_Foolad IS very_old)
#   -- Found (age_mid_difender_1_Sepahan IS young) *AND* (age_mid_difender_2_Sepahan IS young) AND (age_center_forward_Foolad IS very_old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_1_Sepahan IS young)
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_mid_difender_2_Sepahan IS young) AND (age_center_forward_Foolad IS very_old)
#   -- Found (age_mid_difender_2_Sepahan IS young) *AND* (age_center_forward_Foolad IS very_old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_2_Sepahan IS young)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_center_forward_Foolad IS very_old)
#  * Added rule IF f.(c.(age_mid_difender_1_Sepahan IS young) AND f.(c.(age_mid_difender_2_Sepahan IS young) AND c.(age_center_forward_Foolad IS very_old))) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_mid_difender_1_Foolad IS very_old) AND (age_mid_difender_2_Foolad IS middle_age) AND (age_center_forward_Sepahan IS young)
#   -- Found (age_mid_difender_1_Foolad IS very_old) *AND* (age_mid_difender_2_Foolad IS middle_age) AND (age_center_forward_Sepahan IS young)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_1_Foolad IS very_old)
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_mid_difender_2_Foolad IS middle_age) AND (age_center_forward_Sepahan IS young)
#   -- Found (age_mid_difender_2_Foolad IS middle_age) *AND* (age_center_forward_Sepahan IS young)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_2_Foolad IS middle_age)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_center_forward_Sepahan IS young)
#  * Added rule IF f.(c.(age_mid_difender_1_Foolad IS very_old) AND f.(c.(age_mid_difender_2_Foolad IS middle_age) AND c.(age_center_forward_Sepahan IS young))) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_mid_difender_1_Sepahan IS old) AND (age_mid_difender_2_Sepahan IS young) AND (age_center_forward_Foolad IS old)
#   -- Found (age_mid_difender_1_Sepahan IS old) *AND* (age_mid_difender_2_Sepahan IS young) AND (age_center_forward_Foolad IS old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_1_Sepahan IS old)
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_mid_difender_2_Sepahan IS young) AND (age_center_forward_Foolad IS old)
#   -- Found (age_mid_difender_2_Sepahan IS young) *AND* (age_center_forward_Foolad IS old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_2_Sepahan IS young)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_center_forward_Foolad IS old)
#  * Added rule IF f.(c.(age_mid_difender_1_Sepahan IS old) AND f.(c.(age_mid_difender_2_Sepahan IS young) AND c.(age_center_forward_Foolad IS old))) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_mid_difender_1_Sepahan IS old) AND (age_mid_difender_2_Sepahan IS old) AND (age_center_forward_Foolad IS middle_age)
#   -- Found (age_mid_difender_1_Sepahan IS old) *AND* (age_mid_difender_2_Sepahan IS old) AND (age_center_forward_Foolad IS middle_age)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_1_Sepahan IS old)
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_mid_difender_2_Sepahan IS old) AND (age_center_forward_Foolad IS middle_age)
#   -- Found (age_mid_difender_2_Sepahan IS old) *AND* (age_center_forward_Foolad IS middle_age)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_mid_difender_2_Sepahan IS old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_center_forward_Foolad IS middle_age)
#  * Added rule IF f.(c.(age_mid_difender_1_Sepahan IS old) AND f.(c.(age_mid_difender_2_Sepahan IS old) AND c.(age_center_forward_Foolad IS middle_age))) THEN ('result_5', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_left_difender_Foolad IS young) AND (age_right_forward_Sepahan IS very_old)
#   -- Found (age_left_difender_Foolad IS young) *AND* (age_right_forward_Sepahan IS very_old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_difender_Foolad IS young)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_forward_Sepahan IS very_old)
#  * Added rule IF f.(c.(age_left_difender_Foolad IS young) AND c.(age_right_forward_Sepahan IS very_old)) THEN ('result_5', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_left_difender_Sepahan IS young) AND (age_right_forward_Foolad IS very_old)
#   -- Found (age_left_difender_Sepahan IS young) *AND* (age_right_forward_Foolad IS very_old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_difender_Sepahan IS young)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_forward_Foolad IS very_old)
#  * Added rule IF f.(c.(age_left_difender_Sepahan IS young) AND c.(age_right_forward_Foolad IS very_old)) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_left_difender_Foolad IS very_old) AND (age_right_forward_Sepahan IS young)
#   -- Found (age_left_difender_Foolad IS very_old) *AND* (age_right_forward_Sepahan IS young)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_difender_Foolad IS very_old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_forward_Sepahan IS young)
#  * Added rule IF f.(c.(age_left_difender_Foolad IS very_old) AND c.(age_right_forward_Sepahan IS young)) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_left_difender_Sepahan IS old) AND (age_right_forward_Foolad IS old)
#   -- Found (age_left_difender_Sepahan IS old) *AND* (age_right_forward_Foolad IS old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_difender_Sepahan IS old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_forward_Foolad IS old)
#  * Added rule IF f.(c.(age_left_difender_Sepahan IS old) AND c.(age_right_forward_Foolad IS old)) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_left_difender_Sepahan IS old) AND (age_right_forward_Foolad IS middle_age)
#   -- Found (age_left_difender_Sepahan IS old) *AND* (age_right_forward_Foolad IS middle_age)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_difender_Sepahan IS old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_forward_Foolad IS middle_age)
#  * Added rule IF f.(c.(age_left_difender_Sepahan IS old) AND c.(age_right_forward_Foolad IS middle_age)) THEN ('result_5', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_right_difender_Foolad IS young) AND (age_left_forward_Sepahan IS very_old)
#   -- Found (age_right_difender_Foolad IS young) *AND* (age_left_forward_Sepahan IS very_old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_difender_Foolad IS young)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_forward_Sepahan IS very_old)
#  * Added rule IF f.(c.(age_right_difender_Foolad IS young) AND c.(age_left_forward_Sepahan IS very_old)) THEN ('result_5', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_right_difender_Sepahan IS young) AND (age_left_forward_Foolad IS very_old)
#   -- Found (age_right_difender_Sepahan IS young) *AND* (age_left_forward_Foolad IS very_old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_difender_Sepahan IS young)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_forward_Foolad IS very_old)
#  * Added rule IF f.(c.(age_right_difender_Sepahan IS young) AND c.(age_left_forward_Foolad IS very_old)) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_right_difender_Foolad IS very_old) AND (age_left_forward_Sepahan IS young)
#   -- Found (age_right_difender_Foolad IS very_old) *AND* (age_left_forward_Sepahan IS young)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_difender_Foolad IS very_old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_forward_Sepahan IS young)
#  * Added rule IF f.(c.(age_right_difender_Foolad IS very_old) AND c.(age_left_forward_Sepahan IS young)) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_right_difender_Sepahan IS old) AND (age_left_forward_Foolad IS old)
#   -- Found (age_right_difender_Sepahan IS old) *AND* (age_left_forward_Foolad IS old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_difender_Sepahan IS old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_forward_Foolad IS old)
#  * Added rule IF f.(c.(age_right_difender_Sepahan IS old) AND c.(age_left_forward_Foolad IS old)) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (age_right_difender_Sepahan IS old) AND (age_left_forward_Foolad IS middle_age)
#   -- Found (age_right_difender_Sepahan IS old) *AND* (age_left_forward_Foolad IS middle_age)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_right_difender_Sepahan IS old)
#  * Simple clause with parentheses matched
#  * Rule: c.(age_left_forward_Foolad IS middle_age)
#  * Added rule IF f.(c.(age_right_difender_Sepahan IS old) AND c.(age_left_forward_Foolad IS middle_age)) THEN ('result_5', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_mid_difender_1_Foolad IS expensive) AND (price_mid_difender_2_Foolad IS expensive) AND (price_center_forward_Sepahan IS very_cheap)
#   -- Found (price_mid_difender_1_Foolad IS expensive) *AND* (price_mid_difender_2_Foolad IS expensive) AND (price_center_forward_Sepahan IS very_cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_1_Foolad IS expensive)
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_mid_difender_2_Foolad IS expensive) AND (price_center_forward_Sepahan IS very_cheap)
#   -- Found (price_mid_difender_2_Foolad IS expensive) *AND* (price_center_forward_Sepahan IS very_cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_2_Foolad IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_center_forward_Sepahan IS very_cheap)
#  * Added rule IF f.(c.(price_mid_difender_1_Foolad IS expensive) AND f.(c.(price_mid_difender_2_Foolad IS expensive) AND c.(price_center_forward_Sepahan IS very_cheap))) THEN ('result_5', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_mid_difender_1_Sepahan IS expensive) AND (price_mid_difender_2_Sepahan IS expensive) AND (price_center_forward_Foolad IS very_cheap)
#   -- Found (price_mid_difender_1_Sepahan IS expensive) *AND* (price_mid_difender_2_Sepahan IS expensive) AND (price_center_forward_Foolad IS very_cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_1_Sepahan IS expensive)
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_mid_difender_2_Sepahan IS expensive) AND (price_center_forward_Foolad IS very_cheap)
#   -- Found (price_mid_difender_2_Sepahan IS expensive) *AND* (price_center_forward_Foolad IS very_cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_2_Sepahan IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_center_forward_Foolad IS very_cheap)
#  * Added rule IF f.(c.(price_mid_difender_1_Sepahan IS expensive) AND f.(c.(price_mid_difender_2_Sepahan IS expensive) AND c.(price_center_forward_Foolad IS very_cheap))) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_mid_difender_1_Foolad IS very_cheap) AND (price_mid_difender_2_Foolad IS normal) AND (price_center_forward_Sepahan IS expensive)
#   -- Found (price_mid_difender_1_Foolad IS very_cheap) *AND* (price_mid_difender_2_Foolad IS normal) AND (price_center_forward_Sepahan IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_1_Foolad IS very_cheap)
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_mid_difender_2_Foolad IS normal) AND (price_center_forward_Sepahan IS expensive)
#   -- Found (price_mid_difender_2_Foolad IS normal) *AND* (price_center_forward_Sepahan IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_2_Foolad IS normal)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_center_forward_Sepahan IS expensive)
#  * Added rule IF f.(c.(price_mid_difender_1_Foolad IS very_cheap) AND f.(c.(price_mid_difender_2_Foolad IS normal) AND c.(price_center_forward_Sepahan IS expensive))) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_mid_difender_1_Sepahan IS cheap) AND (price_mid_difender_2_Sepahan IS expensive) AND (price_center_forward_Foolad IS cheap)
#   -- Found (price_mid_difender_1_Sepahan IS cheap) *AND* (price_mid_difender_2_Sepahan IS expensive) AND (price_center_forward_Foolad IS cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_1_Sepahan IS cheap)
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_mid_difender_2_Sepahan IS expensive) AND (price_center_forward_Foolad IS cheap)
#   -- Found (price_mid_difender_2_Sepahan IS expensive) *AND* (price_center_forward_Foolad IS cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_2_Sepahan IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_center_forward_Foolad IS cheap)
#  * Added rule IF f.(c.(price_mid_difender_1_Sepahan IS cheap) AND f.(c.(price_mid_difender_2_Sepahan IS expensive) AND c.(price_center_forward_Foolad IS cheap))) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_mid_difender_1_Sepahan IS cheap) AND (price_mid_difender_2_Sepahan IS cheap) AND (price_center_forward_Foolad IS normal)
#   -- Found (price_mid_difender_1_Sepahan IS cheap) *AND* (price_mid_difender_2_Sepahan IS cheap) AND (price_center_forward_Foolad IS normal)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_1_Sepahan IS cheap)
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_mid_difender_2_Sepahan IS cheap) AND (price_center_forward_Foolad IS normal)
#   -- Found (price_mid_difender_2_Sepahan IS cheap) *AND* (price_center_forward_Foolad IS normal)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_mid_difender_2_Sepahan IS cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_center_forward_Foolad IS normal)
#  * Added rule IF f.(c.(price_mid_difender_1_Sepahan IS cheap) AND f.(c.(price_mid_difender_2_Sepahan IS cheap) AND c.(price_center_forward_Foolad IS normal))) THEN ('result_5', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_left_difender_Foolad IS expensive) AND (price_right_forward_Sepahan IS very_cheap)
#   -- Found (price_left_difender_Foolad IS expensive) *AND* (price_right_forward_Sepahan IS very_cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_difender_Foolad IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_forward_Sepahan IS very_cheap)
#  * Added rule IF f.(c.(price_left_difender_Foolad IS expensive) AND c.(price_right_forward_Sepahan IS very_cheap)) THEN ('result_5', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_left_difender_Sepahan IS expensive) AND (price_right_forward_Foolad IS very_cheap)
#   -- Found (price_left_difender_Sepahan IS expensive) *AND* (price_right_forward_Foolad IS very_cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_difender_Sepahan IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_forward_Foolad IS very_cheap)
#  * Added rule IF f.(c.(price_left_difender_Sepahan IS expensive) AND c.(price_right_forward_Foolad IS very_cheap)) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_left_difender_Foolad IS very_cheap) AND (price_right_forward_Sepahan IS expensive)
#   -- Found (price_left_difender_Foolad IS very_cheap) *AND* (price_right_forward_Sepahan IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_difender_Foolad IS very_cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_forward_Sepahan IS expensive)
#  * Added rule IF f.(c.(price_left_difender_Foolad IS very_cheap) AND c.(price_right_forward_Sepahan IS expensive)) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_left_difender_Sepahan IS cheap) AND (price_right_forward_Foolad IS cheap)
#   -- Found (price_left_difender_Sepahan IS cheap) *AND* (price_right_forward_Foolad IS cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_difender_Sepahan IS cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_forward_Foolad IS cheap)
#  * Added rule IF f.(c.(price_left_difender_Sepahan IS cheap) AND c.(price_right_forward_Foolad IS cheap)) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_left_difender_Sepahan IS cheap) AND (price_right_forward_Foolad IS normal)
#   -- Found (price_left_difender_Sepahan IS cheap) *AND* (price_right_forward_Foolad IS normal)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_difender_Sepahan IS cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_forward_Foolad IS normal)
#  * Added rule IF f.(c.(price_left_difender_Sepahan IS cheap) AND c.(price_right_forward_Foolad IS normal)) THEN ('result_5', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_right_difender_Foolad IS expensive) AND (price_left_forward_Sepahan IS very_cheap)
#   -- Found (price_right_difender_Foolad IS expensive) *AND* (price_left_forward_Sepahan IS very_cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_difender_Foolad IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_forward_Sepahan IS very_cheap)
#  * Added rule IF f.(c.(price_right_difender_Foolad IS expensive) AND c.(price_left_forward_Sepahan IS very_cheap)) THEN ('result_5', 'Foolad_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_right_difender_Sepahan IS expensive) AND (price_left_forward_Foolad IS very_cheap)
#   -- Found (price_right_difender_Sepahan IS expensive) *AND* (price_left_forward_Foolad IS very_cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_difender_Sepahan IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_forward_Foolad IS very_cheap)
#  * Added rule IF f.(c.(price_right_difender_Sepahan IS expensive) AND c.(price_left_forward_Foolad IS very_cheap)) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_right_difender_Foolad IS very_cheap) AND (price_left_forward_Sepahan IS expensive)
#   -- Found (price_right_difender_Foolad IS very_cheap) *AND* (price_left_forward_Sepahan IS expensive)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_difender_Foolad IS very_cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_forward_Sepahan IS expensive)
#  * Added rule IF f.(c.(price_right_difender_Foolad IS very_cheap) AND c.(price_left_forward_Sepahan IS expensive)) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_right_difender_Sepahan IS cheap) AND (price_left_forward_Foolad IS cheap)
#   -- Found (price_right_difender_Sepahan IS cheap) *AND* (price_left_forward_Foolad IS cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_difender_Sepahan IS cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_forward_Foolad IS cheap)
#  * Added rule IF f.(c.(price_right_difender_Sepahan IS cheap) AND c.(price_left_forward_Foolad IS cheap)) THEN ('result_5', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (price_right_difender_Sepahan IS cheap) AND (price_left_forward_Foolad IS normal)
#   -- Found (price_right_difender_Sepahan IS cheap) *AND* (price_left_forward_Foolad IS normal)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_right_difender_Sepahan IS cheap)
#  * Simple clause with parentheses matched
#  * Rule: c.(price_left_forward_Foolad IS normal)
#  * Added rule IF f.(c.(price_right_difender_Sepahan IS cheap) AND c.(price_left_forward_Foolad IS normal)) THEN ('result_5', 'Foolad_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(performance_Foolad IS bad)
#  * Added rule IF c.(performance_Foolad IS bad) THEN ('result_6', 'Sepahan_win')
#
#  * Simple clause with parentheses matched
#  * Rule: c.(performance_Sepahan IS good)
#  * Added rule IF c.(performance_Sepahan IS good) THEN ('result_6', 'Sepahan_win')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (performance_Foolad IS bad) AND (performance_Sepahan IS bad)
#   -- Found (performance_Foolad IS bad) *AND* (performance_Sepahan IS bad)
#  * Simple clause with parentheses matched
#  * Rule: c.(performance_Foolad IS bad)
#  * Simple clause with parentheses matched
#  * Rule: c.(performance_Sepahan IS bad)
#  * Added rule IF f.(c.(performance_Foolad IS bad) AND c.(performance_Sepahan IS bad)) THEN ('result_6', 'tie')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (performance_Foolad IS medium) AND (performance_Sepahan IS medium)
#   -- Found (performance_Foolad IS medium) *AND* (performance_Sepahan IS medium)
#  * Simple clause with parentheses matched
#  * Rule: c.(performance_Foolad IS medium)
#  * Simple clause with parentheses matched
#  * Rule: c.(performance_Sepahan IS medium)
#  * Added rule IF f.(c.(performance_Foolad IS medium) AND c.(performance_Sepahan IS medium)) THEN ('result_6', 'tie')
#
#  * 104 rules successfully added

# %%
# Q2_graded

FS.set_variable("performance_Sepahan", 4) 
FS.set_variable("performance_Foolad", 3) 

FS.set_variable("price_goalkeeper_Foolad", 270)
FS.set_variable("age_goalkeeper_Foolad", 27)

FS.set_variable("price_left_difender_Foolad", 338)
FS.set_variable("age_left_difender_Foolad", 23)

FS.set_variable("price_right_difender_Foolad", 428)
FS.set_variable("age_right_difender_Foolad", 24)

FS.set_variable("price_mid_difender_1_Foolad", 405)
FS.set_variable("age_mid_difender_1_Foolad", 25)

FS.set_variable("price_mid_difender_2_Foolad", 383)
FS.set_variable("age_mid_difender_2_Foolad", 22)

FS.set_variable("price_mid_fielder_1_Foolad", 225)
FS.set_variable("age_mid_fielder_1_Foolad", 32)

FS.set_variable("price_mid_fielder_2_Foolad", 225)
FS.set_variable("age_mid_fielder_2_Foolad", 29)

FS.set_variable("price_mid_fielder_3_Foolad", 585)
FS.set_variable("age_mid_fielder_3_Foolad", 29)

FS.set_variable("price_right_forward_Foolad", 496)
FS.set_variable("age_right_forward_Foolad", 28)

FS.set_variable("price_left_forward_Foolad", 405)
FS.set_variable("age_left_forward_Foolad", 22)

FS.set_variable("price_center_forward_Foolad", 405)
FS.set_variable("age_center_forward_Foolad", 31)


# ==========================

FS.set_variable("price_goalkeeper_Sepahan", 405)
FS.set_variable("age_goalkeeper_Sepahan", 33)

FS.set_variable("price_left_difender_Sepahan", 1080)
FS.set_variable("age_left_difender_Sepahan", 25)

FS.set_variable("price_right_difender_Sepahan", 698)
FS.set_variable("age_right_difender_Sepahan", 29)

FS.set_variable("price_mid_difender_1_Sepahan", 450)
FS.set_variable("age_mid_difender_1_Sepahan", 29)

FS.set_variable("price_mid_difender_2_Sepahan", 315)
FS.set_variable("age_mid_difender_2_Sepahan", 31)

FS.set_variable("price_mid_fielder_1_Sepahan", 585)
FS.set_variable("age_mid_fielder_1_Sepahan", 20)

FS.set_variable("price_mid_fielder_2_Sepahan", 495)
FS.set_variable("age_mid_fielder_2_Sepahan", 29)

FS.set_variable("price_mid_fielder_3_Sepahan", 450)
FS.set_variable("age_mid_fielder_3_Sepahan", 32)

FS.set_variable("price_right_forward_Sepahan", 563)
FS.set_variable("age_right_forward_Sepahan", 29)

FS.set_variable("price_left_forward_Sepahan", 270)
FS.set_variable("age_left_forward_Sepahan", 33)

FS.set_variable("price_center_forward_Sepahan", 540)
FS.set_variable("age_center_forward_Sepahan", 27)



res = FS.inference()

# %%
# Q2_graded

# dar sorati score ra dar nazar migirim ke kochektar az -1 ya bozorgtar az 1 bashad

Sepahan_score = 0
Foolad_score = 0

for i in range(1,7):
    if res[f"result_{i}"] < -1:
        Sepahan_score += 1
    elif res[f"result_{i}"] > 1:
        Foolad_score += 1

print(f"This matche's score is Sepahan {Sepahan_score}-{Foolad_score} Foolad")
# Out:
# This matche's score is Sepahan 1-1 Foolad

# %% [markdown]
# # <font color='red'>Submission</font>
#
# 1. Sign up in [Gradescope](https://www.gradescope.com) with proper name and student ID.
# 2. Fill in your full name (seperated by single spaces) and student ID in the beginning of this notebook.
# 3. After you're done with this notebook, you should do the following:
#   - Clear all outputs of the notebook.
#   ![clear all outputs](https://i.ibb.co/y6FrttB/Screen-Shot-2021-03-21-at-01-51-42.png)
#   - Run all of the cells (if you skipped a question just leave the cell unchanged), and make sure all of your outputs are correct.
#   ![run all](https://i.ibb.co/cgRcBZ0/Screen-Shot-2021-03-21-at-01-54-58.png)
#   - Save your notebook.
#
#   - If you're using Colab, download your notebook.
#   ![download ipynb](https://i.ibb.co/2KxYM6K/Screen-Shot-2021-03-21-at-02-03-50.png)
#
#   - Put the notebook file you just downloaded and `convert.py` in the same folder run the following command:
#   ```bash
#   python convert.py
#   ```
#   This will export your code for each question into a `.py` file.
#     - **Note**: if you want to add more cells, add this to the **first** line of the cell:
#   ```python
#   # Q2_graded
#   ```
#   according to the question number.
#   - There are 2 assignments in Gradescope:
#
#     You should upload your **codes** and your **notebook** in `HW4` section and your final report for all of the questions as a **single pdf** file in `HW4 - Report`. Autograder will automatically check for:
#     - `CI002_HW4.ipynb`
#     - `Q2.py`
#     - Your name and ID in the beginning of `.ipynb` file.
#
#     It is important that you <font color='red'>**don't**</font> change the names of these files before submission.
#
# 4. If you pass the autograder, you're good to go.
